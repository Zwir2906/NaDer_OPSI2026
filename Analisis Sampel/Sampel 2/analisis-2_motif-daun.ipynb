# %% [markdown]
# # Sampel 2, Motif Daun dan Bunga

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import skan
from utils import *

# %%
leaf = cv2.imread("sampel-2_motif-daun.png")
leaf_binary = binarize(leaf)

# %%
plt.imshow(leaf_binary[1100:2300, 100:1300], cmap='grey')

# %%
num_object, object_map, object_stats, object_centroids = cv2.connectedComponentsWithStats(leaf_binary)

# %%
plt.figure(figsize=(10,10))
plt.imshow(object_map[1100:2300, 100:1300], cmap='nipy_spectral', interpolation='nearest')
plt.colorbar(shrink=0.5)

num_object
# Out:
# 102

# %%
areas = object_stats[1:, cv2.CC_STAT_AREA]

sns.histplot(areas, kde=True, bins=30)

summarizeData(areas, "Object Areas")
# Out:
# DATA SUMMARY of [Object Areas]:
# Num     : 101
# Mean    : 4811.7228
# SD      : 6490.1887
# SD rel  : 134.88%
# Median  : 2594.0000
# MAD     : 1270.0000
# MAD rel : 48.96%
# Min     : 697.0000
# Max     : 44671.0000
# {'num': 101,
#  'mean': 4811.722772277228,
#  'sd': 6490.188659356203,
#  'median': 2594.0,
#  'mad': 1270.0,
#  'min': 697,
#  'max': 44671}
